# %% [markdown]
# <a href="https://colab.research.google.com/github/Saul-Ochoa/RepositorioUPC/blob/main/Simulaci%C3%B3n_UPC_GERENCIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Autor Saúl Kevin Ochoa Salazar**
#
# # **Codigo u201911664**

# %% [markdown]
# ## Libreria

# %%
pip install simpy
# Out:
# Requirement already satisfied: simpy in /usr/local/lib/python3.10/dist-packages (4.0.1)

# %% [markdown]
# ## Codigo

# %%
import random
import simpy
import matplotlib.pyplot as plt
import statistics

simulacion_riesgos = [
    {
        'codigo': 'RIES-01',
        'presupuesto_minimo': 3504,
        'presupuesto_real': 8500,
        'presupuesto_maximo': 9500,
    },
    {
        'codigo': 'RIES-02',
        'presupuesto_minimo': 1230,
        'presupuesto_real': 5050,
        'presupuesto_maximo': 6250,
    },
    {
        'codigo': 'RIES-03',
        'presupuesto_minimo': 9933,
        'presupuesto_real': 10500,
        'presupuesto_maximo': 11650,
    },
    {
        'codigo': 'RIES-04',
        'presupuesto_minimo': 1113,
        'presupuesto_real': 3800,
        'presupuesto_maximo': 4200,
    },
    {
        'codigo': 'RIES-05',
        'presupuesto_minimo': 4750,
        'presupuesto_real': 8250,
        'presupuesto_maximo': 9250,
    },
    {
        'codigo': 'RIES-06',
        'presupuesto_minimo': 2388,
        'presupuesto_real': 5500,
        'presupuesto_maximo': 6500,
    }
]

# Función de simulación
def simulacion(env, presupuesto_minimo, presupuesto_real, presupuesto_maximo):
    for riesgo in simulacion_riesgos:
        presupuesto_minimo += riesgo['presupuesto_minimo']
        presupuesto_real += riesgo['presupuesto_real']
        presupuesto_maximo += riesgo['presupuesto_maximo']

        # Simular el presupuesto real utilizando una distribución aleatoria
        presupuesto_simulado = random.uniform(riesgo['presupuesto_real'], riesgo['presupuesto_maximo'])
        presupuesto_real += presupuesto_simulado

    return presupuesto_minimo, presupuesto_real, presupuesto_real + (presupuesto_real - presupuesto_minimo)

# Ejecutar mil simulaciones
num_simulaciones = 1000
resultados_presupuesto = []

for _ in range(num_simulaciones):
    random.seed()  # Reiniciar la semilla aleatoria para cada simulación
    env = simpy.Environment()
    presupuesto_minimo = 22918.0
    presupuesto_real = 0
    presupuesto_maximo = 0
    presupuesto_minimo, presupuesto_real, presupuesto_maximo = simulacion(env, presupuesto_minimo, presupuesto_real, presupuesto_maximo)
    resultados_presupuesto.append(presupuesto_real - presupuesto_maximo)

# Calcular métricas
media = statistics.mean(resultados_presupuesto)
mediana = statistics.median(resultados_presupuesto)
desviacion_estandar = statistics.stdev(resultados_presupuesto)


error = desviacion_estandar / (num_simulaciones ** 0.5)

# %%
print("Presupuesto mínimo: S/{:.2f}".format(presupuesto_minimo))
print("Presupuesto real: S/{:.2f}".format(presupuesto_real))
print("Presupuesto máximo: S/{:.2f}".format(presupuesto_maximo))
print("Riesgo presupuestal: S/{:.2f}".format(presupuesto_real - presupuesto_maximo))
print("Media: {:.2f}".format(media))
print("Mediana: {:.2f}".format(mediana))
print("Desviación estándar: {:.2f}".format(desviacion_estandar))
print("Error: {:.2f}".format(error))
# Out:
# Presupuesto mínimo: S/45836.00
# Presupuesto real: S/87338.97
# Presupuesto máximo: S/128841.93
# Riesgo presupuestal: S/-41502.97
# Media: -40241.41
# Mediana: -40233.71
# Desviación estándar: 694.81
# Error: 21.97

# %%
# Crear el gráfico de errores
errores = [result - presupuesto_maximo for result in resultados_presupuesto]
plt.figure(figsize=(10, 6))
plt.plot(errores)
plt.xlabel('Simulación')
plt.ylabel('Error')
plt.title('Errores de Simulación')
plt.grid(True)


plt.show()

# %% [markdown]
# ## Grafico de la Simulacion

# %%
plt.figure(figsize=(10, 6))
plt.hist(resultados_presupuesto, bins=20, edgecolor='black')
plt.xlabel('Diferencia de Presupuesto')
plt.ylabel('Frecuencia')
plt.title('Distribución de Riesgo Presupuestal')
plt.grid(True)

plt.show()

# %%
import plotly.express as px
fig = px.histogram(resultados_presupuesto, nbins=20, labels={'value': 'Diferencia de Presupuesto', 'count': 'Frecuencia'})
fig.update_layout(title='Distribución de Riesgo Presupuestal', xaxis=dict(title='Diferencia de Presupuesto'), yaxis=dict(title='Frecuencia'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="60564456-a9f2-4718-bfcf-b035498aa650" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60564456-a9f2-4718-bfcf-b035498aa650")) {                    Plotly.newPlot(                        "60564456-a9f2-4718-bfcf-b035498aa650",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=0<br>Diferencia de Presupuesto=%{x}<br>count=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","nbinsx":20,"offsetgroup":"0","orientation":"v","showlegend":true,"x":[-39826.0734848094,-41047.44378622323,-40294.86618121574,-39669.737846218966,-39124.49840162993,-41421.270548961285,-40071.55953656994,-40711.7054748527,-39480.27631482862,-41250.77135526748,-40617.34714002008,-40880.343421671,-40403.260980688035,-39890.47860954079,-40529.586644715324,-41325.22665697441,-39303.857911633546,-41136.052852333814,-39329.88587926398,-40242.232292264176,-40128.31858875051,-40632.51612280685,-41289.97326528357,-39977.086731985895,-41394.99067710058,-41591.243796643714,-39916.68883300254,-40018.1737602067,-40006.82036229878,-41561.03538270063,-39161.457494192204,-40806.72130547828,-39733.556744475485,-40258.12540658214,-39941.47093670917,-39532.104172515945,-41124.58273777274,-40179.433576004056,-40189.52683721349,-38900.633915760554,-40744.26553264253,-39966.57978102655,-40782.606446497884,-41299.424405190206,-40265.68596747526,-39955.18711994086,-40780.39496128354,-40422.108409351815,-39632.376867325875,-39524.0927609262,-39929.32082126649,-40603.41017864323,-40285.84286118866,-40461.706950740074,-39642.71713291068,-40879.925665319504,-40251.67857323545,-40085.927469575836,-40463.20967081266,-40737.35402220917,-41152.92451227472,-38955.73528483612,-39908.14906778431,-40006.57859009263,-41580.94890752193,-39976.59254105316,-41663.83148968029,-40285.897074382665,-40707.77321579965,-40769.951157588876,-40372.37175300541,-40844.03757783183,-40591.79559793339,-40198.67004547645,-40494.983691220594,-39768.67372819052,-40229.91216298782,-39494.64899498434,-41223.61418472724,-40715.80298515834,-40596.46605956541,-39793.22058227897,-40371.30448582492,-39664.443427136095,-41210.709801784615,-40627.80368059188,-40797.32505788187,-40495.11657046016,-39025.925285478166,-40946.41604683921,-38641.878791312614,-39786.25031867692,-41317.59149653572,-40363.88551276816,-40390.85412707459,-40864.656996220525,-41251.390642707556,-40828.88146976016,-39783.32626576506,-40704.53277088776,-39148.814743935596,-40361.98414091543,-39951.00416829869,-40322.723674429086,-41234.01891700829,-40676.383017772285,-41034.50297770275,-40917.02185696317,-38368.15138034885,-40267.877955475706,-40844.83035270992,-41299.219614165806,-40108.69980198049,-39891.24998468159,-39499.309002915834,-40724.15676672288,-40662.7360425981,-40252.22648271802,-40443.274028084896,-41247.826548895275,-40648.420634069844,-39582.82310043526,-40010.50784700076,-40661.36870463479,-39484.276465386385,-39742.867108301565,-39839.88027815714,-40431.0632087547,-39683.50624950204,-40029.44369917094,-41591.9960819282,-38858.54435068855,-40018.128332918044,-40674.962478403235,-40179.06801509921,-40395.18468176681,-41259.68695439592,-39342.33371610982,-41874.927777672376,-39917.75878908814,-39436.963265729995,-40616.15967190926,-39544.204963032316,-41229.451581751506,-39487.1555239702,-39304.29112176654,-39841.26161827936,-40068.67118420027,-40009.053975760515,-39997.28511410588,-40274.73003605395,-40371.67285853032,-40799.45752575417,-39073.99461795774,-39736.84353497953,-40654.465724683134,-40842.42216020005,-40252.82109480888,-40824.04517259718,-39005.08752985303,-39384.55269931092,-40012.87865746398,-40181.76513983196,-40228.97619114739,-39756.127947 ...
